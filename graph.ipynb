# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
x = np.arange(-10, 20)
y = x**2
ax.plot(x, y)
ax.set_xlabel("Time")
ax.set_ylabel("Stress")
plt.savefig('graph.png')
